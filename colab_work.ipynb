# %%
# !git clone https://github.com/shreyansh6726/StockBazaar.git
# Out:
# Cloning into 'StockBazaar'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 54 (delta 22), reused 37 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (54/54), 342.66 KiB | 7.97 MiB/s, done.
# Resolving deltas: 100% (22/22), done.
